# %%
# %load_ext autoreload

# %autoreload 2
from experiments import *

# %%
a =3
b = 6
c = 8
alfa = 0.2
beta = 0.1
mu1 = [2,10,10]
mu2 = [-2,-10,-10]


sigma1 = np.array([[np.power(a,2),alfa*a*b,alfa*a*c],[alfa*a*b,np.power(b,2),beta*b*c],[alfa*a*c,beta*b*c,np.power(c,2)]])

sigma2 = np.array([[np.power(c,2),beta*b*c,beta*a*c],[alfa*b*c,np.power(b,2),alfa*a*b],[beta*a*c,alfa*a*b,np.power(a,2)]])


# sigma1 = np.array([[1,0,0],[0,1,0],[0,0,1]])
# sigma2 = np.array([[5,0,0],[0,5,0],[0,0,5]])

w1, v1 = LA.eig(sigma1)

w2, v2 = LA.eig(sigma2)


X1 = generate_Gaussian_random_vector(mu1,sigma1,3,200)

X2 = generate_Gaussian_random_vector(mu2,sigma2,3,200)

print(f"Sigma for x1 is\n {sigma1} \n")
print(f"Mu for x1 is\n {mu1}\n")
print(f"Sigma for x2 is\n {sigma2} \n")
print(f"Mu for x2 is\ {mu2}\n")
      
      

display(X1,X2,40)

X1_test = generate_Gaussian_random_vector(mu1,sigma1,3,200)
X2_test = generate_Gaussian_random_vector(mu2,sigma2,3,200)

A,B,C = generate_classifier(sigma1,mu1,sigma2,mu2)
print(A[2,2])
# Out:
# Sigma for x1 is
#  [[ 9.   3.6  4.8]
#  [ 3.6 36.   4.8]
#  [ 4.8  4.8 64. ]]
#
# Mu for x1 is
#  [2, 10, 10]
#
# Sigma for x2 is
#  [[64.   4.8  2.4]
#  [ 9.6 36.   3.6]
#  [ 2.4  3.6  9. ]]
#
# Mu for x2 is\ [-2, -10, -10]
#
# 10.319650766831694
# 10.319650766831694
# 10.319650766831694
# 0.09999441371990393

# %%
#### print(sigma1.shape)
# print(mu1.shape)


sigma_1,mu_1,sigma_2,mu_2 = MaximumLiklihood(X1,X2)
print(f"The true sigma 1 is \n{sigma1}\n")
print(f"The estimated sigma1 using ML is \n {sigma_1}\n")
print(f"The estimated mu1 using ML is \n {mu_1.T}\n")

print(f"The true sigma 2 is \n{sigma2}\n")
print(f"The estimated sigma2 using ML is \n {sigma_2}\n")
print(f"The estimated mu2 using ML is \n {mu_2.T}\n")


sigma1_points, mu1_points = ML_points(X1,X2,sigma1,np.array(mu1).T)
plot_points(sigma1_points,len(sigma1_points))
plot_points(mu1_points,len(mu1_points))
A,B,C = generate_classifier(sigma_1,mu_1.T[0],sigma_2,mu_2.T[0])
z1,z2,z3 = get_points(A,B,C,0)



display_x3(X1_test,X2_test,z1,z2,z3,40)

z1_2,z2_2,z3_2 = get_points_x1(A,B,C,7)
display_x1(X1_test,X2_test,z1_2,z2_2,z3_2,40)
# Out:
# The true sigma 1 is
# [[ 9.   3.6  4.8]
#  [ 3.6 36.   4.8]
#  [ 4.8  4.8 64. ]]
#
# The estimated sigma1 using ML is
#  [[ 8.17059317  2.7766217   5.33118191]
#  [ 2.7766217  40.29838842  3.69903901]
#  [ 5.33118191  3.69903901 53.97938398]]
#
# The estimated mu1 using ML is
#  [[ 1.9576727   9.12215068 10.31965077]]
#
# The true sigma 2 is
# [[64.   4.8  2.4]
#  [ 9.6 36.   3.6]
#  [ 2.4  3.6  9. ]]
#
# The estimated sigma2 using ML is
#  [[56.57471119 14.3240347   5.9618725 ]
#  [14.3240347  46.32386305  6.789939  ]
#  [ 5.9618725   6.789939    9.74700699]]
#
# The estimated mu2 using ML is
#  [[ -1.79818994  -9.48698383 -10.16846264]]
#
# [[ 1.9576727 ]
#  [ 9.12215068]
#  [10.31965077]]
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# (3, 1)
# (3,)
# ()
# (3, 3)
# ()
# (3, 3)
# ()
# (3, 3)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     243         try:
# --> 244             return self._assumptions[fact]
#     245         except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     243         try:
# --> 244             return self._assumptions[fact]
#     245         except KeyError:
#
# KeyError: 'real'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     243         try:
# --> 244             return self._assumptions[fact]
#     245         except KeyError:
#
# KeyError: 'imaginary'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     243         try:
# --> 244             return self._assumptions[fact]
#     245         except KeyError:
#
# KeyError: 'odd'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     243         try:
# --> 244             return self._assumptions[fact]
#     245         except KeyError:
#
# KeyError: 'integer'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     243         try:
# --> 244             return self._assumptions[fact]
#     245         except KeyError:
#
# KeyError: 'rational'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-aa9772e564c1> in <module>
#      18 plot_points(mu1_points,len(mu1_points))
#      19 A,B,C = generate_classifier(sigma_1,mu_1.T[0],sigma_2,mu_2.T[0])
# ---> 20 z1,z2,z3 = get_points(A,B,C,0)
#      21
#      22
#
# ~/Pattern recognition/experiments.py in get_points(a, b, d, x3)
#     162     for x1 in np.arange(-100, 100, 0.5):
#     163 #         a =  list(solveset(Eq(A[0,0]*x1**2 + A[1,1]*y**2 + A[2,2]*x3**2,0 + (A[1,0]+A[0,1])*x1*y+ (A[2,0]+A[0,2])*x1*x3 + (A[1,2]+A[2,1])*y*x3,0),y))
# --> 164         v =  list(solveset(Eq(a[0,0]*(x1**2) + a[1,1]*(y**2) + a[2,2]*(x3**2) + (a[0,1]+a[1,0])*x1*y+ (a[0,2]+a[2,0])*x1*x3 + (a[1,2]+a[2,1])*y*x3 + (b[0]*x1) + (b[1]*y) + (b[2] * x3) + d,0),y))
#     165         if type(v[0])is not Add:
#     166             if len(v) > 1 :
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solveset.py in solveset(f, symbol, domain)
#    1712     f = piecewise_fold(f)
#    1713
# -> 1714     return _solveset(f, symbol, domain, _check=True)
#    1715
#    1716
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solveset.py in _solveset(f, symbol, domain, _check)
#     989         if isinstance(result, FiniteSet):
#     990             # check the result for invalid solutions
# --> 991             result = FiniteSet(*[s for s in result
#     992                       if isinstance(s, RootOf)
#     993                       or domain_check(fx, symbol, s)])
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solveset.py in <listcomp>(.0)
#     991             result = FiniteSet(*[s for s in result
#     992                       if isinstance(s, RootOf)
# --> 993                       or domain_check(fx, symbol, s)])
#     994
#     995     return result
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solveset.py in domain_check(f, symbol, p)
#     407     if p.is_infinite:
#     408         return False
# --> 409     return _domain_check(f, symbol, p)
#     410
#     411
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solveset.py in _domain_check(f, symbol, p)
#     414     if f.is_Atom and f.is_finite:
#     415         return True
# --> 416     elif f.subs(symbol, p).is_infinite:
#     417         return False
#     418     else:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in subs(self, *args, **kwargs)
#     995             rv = self
#     996             for old, new in sequence:
# --> 997                 rv = rv._subs(old, new, **kwargs)
#     998                 if not isinstance(rv, Basic):
#     999                     break
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in _subs(self, old, new, **hints)
#    1109         rv = self._eval_subs(old, new)
#    1110         if rv is None:
# -> 1111             rv = fallback(self, old, new)
#    1112         return rv
#    1113
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in fallback(self, old, new)
#    1086                     args[i] = arg
#    1087             if hit:
# -> 1088                 rv = self.func(*args)
#    1089                 hack2 = hints.get('hack2', False)
#    1090                 if hack2 and self.is_Mul and not rv.is_Mul:  # 2-arg hack
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/relational.py in __new__(cls, lhs, rhs, **options)
#     428                 # see if the difference evaluates
#     429                 dif = lhs - rhs
# --> 430                 z = dif.is_zero
#     431                 if z is not None:
#     432                     if z is False and dif.is_commutative:  # issue 10728
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     246             if self._assumptions is self.default_assumptions:
#     247                 self._assumptions = self.default_assumptions.copy()
# --> 248             return _ask(fact, self)
#     249
#     250     getit.func_name = as_property(fact)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     289         pass
#     290     else:
# --> 291         a = evaluate(obj)
#     292         if a is not None:
#     293             assumptions.deduce_all_facts(((fact, a),))
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/add.py in _eval_is_zero(self)
#     546         im = False
#     547         for a in self.args:
# --> 548             if a.is_real:
#     549                 if a.is_zero:
#     550                     z += 1
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     246             if self._assumptions is self.default_assumptions:
#     247                 self._assumptions = self.default_assumptions.copy()
# --> 248             return _ask(fact, self)
#     249
#     250     getit.func_name = as_property(fact)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     289         pass
#     290     else:
# --> 291         a = evaluate(obj)
#     292         if a is not None:
#     293             assumptions.deduce_all_facts(((fact, a),))
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/mul.py in _eval_is_real(self)
#    1161
#    1162     def _eval_is_real(self):
# -> 1163         return self._eval_real_imag(True)
#    1164
#    1165     def _eval_real_imag(self, real):
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/mul.py in _eval_real_imag(self, real)
#    1170             if t.is_complex is False:
#    1171                 return False
# -> 1172             elif t.is_imaginary:  # I
#    1173                 real = not real
#    1174             elif t.is_real:  # 2
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     246             if self._assumptions is self.default_assumptions:
#     247                 self._assumptions = self.default_assumptions.copy()
# --> 248             return _ask(fact, self)
#     249
#     250     getit.func_name = as_property(fact)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     289         pass
#     290     else:
# --> 291         a = evaluate(obj)
#     292         if a is not None:
#     293             assumptions.deduce_all_facts(((fact, a),))
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/power.py in _eval_is_imaginary(self)
#     601         if self.base.is_real is False:  # we already know it's not imag
#     602             i = arg(self.base)*self.exp/S.Pi
# --> 603             isodd = (2*i).is_odd
#     604             if isodd is not None:
#     605                 return isodd
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     246             if self._assumptions is self.default_assumptions:
#     247                 self._assumptions = self.default_assumptions.copy()
# --> 248             return _ask(fact, self)
#     249
#     250     getit.func_name = as_property(fact)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     289         pass
#     290     else:
# --> 291         a = evaluate(obj)
#     292         if a is not None:
#     293             assumptions.deduce_all_facts(((fact, a),))
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/mul.py in _eval_is_odd(self)
#    1321
#    1322     def _eval_is_odd(self):
# -> 1323         is_integer = self.is_integer
#    1324
#    1325         if is_integer:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     246             if self._assumptions is self.default_assumptions:
#     247                 self._assumptions = self.default_assumptions.copy()
# --> 248             return _ask(fact, self)
#     249
#     250     getit.func_name = as_property(fact)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     289         pass
#     290     else:
# --> 291         a = evaluate(obj)
#     292         if a is not None:
#     293             assumptions.deduce_all_facts(((fact, a),))
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/mul.py in _eval_is_integer(self)
#    1144
#    1145     def _eval_is_integer(self):
# -> 1146         is_rational = self.is_rational
#    1147
#    1148         if is_rational:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in getit(self)
#     246             if self._assumptions is self.default_assumptions:
#     247                 self._assumptions = self.default_assumptions.copy()
# --> 248             return _ask(fact, self)
#     249
#     250     getit.func_name = as_property(fact)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     301             continue
#     302         if pk in handler_map:
# --> 303             _ask(pk, obj)
#     304
#     305             # we might have found the value of fact
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     301             continue
#     302         if pk in handler_map:
# --> 303             _ask(pk, obj)
#     304
#     305             # we might have found the value of fact
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     301             continue
#     302         if pk in handler_map:
# --> 303             _ask(pk, obj)
#     304
#     305             # we might have found the value of fact
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     301             continue
#     302         if pk in handler_map:
# --> 303             _ask(pk, obj)
#     304
#     305             # we might have found the value of fact
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     301             continue
#     302         if pk in handler_map:
# --> 303             _ask(pk, obj)
#     304
#     305             # we might have found the value of fact
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     291         a = evaluate(obj)
#     292         if a is not None:
# --> 293             assumptions.deduce_all_facts(((fact, a),))
#     294             return a
#     295
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/facts.py in deduce_all_facts(self, facts)
#     535             for bidx in beta_maytrigger:
#     536                 bcond, bimpl = beta_rules[bidx]
# --> 537                 if all(self.get(k) is v for k, v in bcond):
#     538                     facts.append(bimpl)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/facts.py in <genexpr>(.0)
#     535             for bidx in beta_maytrigger:
#     536                 bcond, bimpl = beta_rules[bidx]
# --> 537                 if all(self.get(k) is v for k, v in bcond):
#     538                     facts.append(bimpl)
#
# KeyboardInterrupt:

# %%
sigma0 = np.array([[1,0,0],[0,1,0],[0,0,1]])
mu0 = np.array([0,0,0])
mu1_bays,mu2_bays = Baysian(X1,X2,sigma1,sigma2,sigma0,mu0)
print(mu1_bays)
print
A,B,C = generate_classifier(sigma1,mu1_bays,sigma2,mu2_bays)
z1,z2,z3 = get_points(A,B,C,0)
display_x3(X1_test,X2_test,z1,z2,z3,40)

z1_2,z2_2,z3_2 = get_points_x1(A,B,C,7)
display_x1(X1_test,X2_test,z1_2,z2_2,z3_2,40)
# Out:
# [1.54143231 9.01294049 7.29582151]

# %%
mu1_n_points = baysian_n_points(X1,X2,sigma1,sigma2,mu1,mu2,sigma0,mu0)
plot_Baysian(mu1_n_points, len(X1[0]))

A,B,C = generate_classifier(sigma1,mu_1,sigma2,mu_2)
z1,z2,z3 = get_points(A,B,C,0)

display_x3(X1_test,X2_test,z1,z2,z3,40)
# Out:
# 200
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-6ff6cdabb3bc> in <module>
#       3
#       4 A,B,C = generate_classifier(sigma1,mu_1,sigma2,mu_2)
# ----> 5 z1,z2,z3 = get_points(A,B,C,0)
#       6
#       7 display_x3(X1_test,X2_test,z1,z2,z3,40)
#
# ~/Pattern recognition/experiments.py in get_points(a, b, d, x3)
#     162     for x1 in np.arange(-100, 100, 0.5):
#     163 #         a =  list(solveset(Eq(A[0,0]*x1**2 + A[1,1]*y**2 + A[2,2]*x3**2,0 + (A[1,0]+A[0,1])*x1*y+ (A[2,0]+A[0,2])*x1*x3 + (A[1,2]+A[2,1])*y*x3,0),y))
# --> 164         v =  list(solveset(Eq(a[0,0]*(x1**2) + a[1,1]*(y**2) + a[2,2]*(x3**2) + (a[0,1]+a[1,0])*x1*y+ (a[0,2]+a[2,0])*x1*x3 + (a[1,2]+a[2,1])*y*x3 + (b[0]*x1) + (b[1]*y) + (b[2] * x3) + d,0),y))
#     165         if type(v[0])is not Add:
#     166             if len(v) > 1 :
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
mu1_n_points = baysian_n_points(X1,X2,sigma1,sigma2,mu1,mu2,sigma0,mu0)
plot_Baysian(mu1_n_points, len(X1[0]))
# Out:
# 200

# %%
sigma0 = np.array([[1,0,0],[0,1,0],[0,0,1]])
mu0 = np.array([0,0,0])
leave_one_out('ML',X1_test,X2_test,sigma1,sigma2,sigma0,mu0)
# Out:
# 95.5

# %%
x1_dist,x2_dist = parzen_window_intervals(X1,X2,0.7)
plot_univariate_prob(x1_dist,x2_dist)

# %%
x1_dens,x2_dens = parzen_window_prob_density(X1,X2,1)
print(x1_dens.shape)
print(X1.shape)
plot_prob_density(x1_dens,x2_dens,X1,X2)

# %%
z1,z2,z3 = get_points(A,B,C,0)

# %%
print(mu1)

# %%
print(sigma1)

# %%
print(mu2)

# %%
print(sigma2)

# %%
display(X1,X2,50)

# %%
z1_2,z2_2,z3_2 = get_points_x1(A,B,C,7)

# %%
display(X1,X2,z1,z2,z3)
display_x1(X1,X2,z1_2,z2_2,z3_2)

# %%
x1_test = generate_Gaussian_random_vector(mu1,sigma1,3,200)
x2_test = generate_Gaussian_random_vector(mu2,sigma2,3,200)

# %%
test_classifier(A,B,C,x1_test,x2_test)

# %%
x1_after,x2_after,sigma1_diag,sigma2_diag,mu1_diag,mu2_diag,v_z = diagonalize(a,b,c,alfa,beta,X1,w1,v1,X2,w2,v2,sigma1,sigma2,mu1,mu2)

# %%
display(x1_after,x2_after,10)

# %%
A_,B_,C_ = generate_classifier(sigma1_diag,mu1_diag,sigma2_diag,mu2_diag)

# %%
print(np.cov(x1_after),np.cov(x2_after))

# %%
z1,z2,z3 = get_points(A_,B_,C_,-1)

# %%
z1_x1,z2_x1,z3_x1 = get_points_x1(A_,B_,C_,2)

# %%
display_x3(x1_after,x2_after,
        z1,z2,z3)
display_x1(x1_after,x2_after,
        z1_x1,z2_x1,z3_x1)

# %%
print(np.cov(x1_after))
print(np.cov(x2_after))
print(np.mean(x1_after))

# %%
test_classifier(A_,B_,C_,x1_after,x2_after)

# %%
x1_test_diag = diagonalize_point(x1_test,v1,w1,v2,v_z)

# %%
x2_test_diag = diagonalize_point(x2_test,v1,w1,v2,v_z)

# %%
test_classifier(A_,B_,C_,x1_test_diag,x2_test_diag)
