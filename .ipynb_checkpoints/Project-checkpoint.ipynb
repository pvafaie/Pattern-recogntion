# %%
# %load_ext autoreload

# %autoreload 2
from experiments import *
import numpy as np
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = get_data()
X1 = data[np.where(data[:,-1] == 1)].astype(float)
X2 = data[np.where(data[:,-1] == 0)].astype(float)
X1 = X1[:,:-1].T
X2 = X2[:,:-1].T

# %%
x1_dist,x2_dist = parzen_window_intervals(X1,X2,1,200)
# Out:
# 0

# %%
plot_univariate_prob(x1_dist,x2_dist,200)
# Out:
# the summ of x1_dist is 1.0
# The sample mean for x1, first dimension is 0.14156474820143886
# The sample varience for x1, first dimension is 7.753105853100263
# The sample mean for x2, first dimension is 0.13130368098159512
# The sample varience for x2, first dimension is 6.648997123653663
# the summ of x1_dist is 1.0
# The sample mean for x1, first dimension is 0.002829781573904088
# The sample varience for x1, first dimension is 0.16954071912215177
# The sample mean for x2, first dimension is 0.0025291554889404246
# The sample varience for x2, first dimension is 0.17951910317291453
# the summ of x1_dist is 1.0
# The sample mean for x1, first dimension is 0.335704964847394
# The sample varience for x1, first dimension is 44.41873246192324
# The sample mean for x2, first dimension is 0.32288343558282206
# The sample varience for x2, first dimension is 41.06898396440934
# the summ of x1_dist is 1.0
# The sample mean for x1, first dimension is 0.44333755975739864
# The sample varience for x1, first dimension is 77.74806554381696
# The sample mean for x2, first dimension is 0.45282305154935254
# The sample varience for x2, first dimension is 81.13351768982977
# the summ of x1_dist is 1.0
# The sample mean for x1, first dimension is 0.34814748113945426
# The sample varience for x1, first dimension is 47.793556181523755
# The sample mean for x2, first dimension is 0.3954085398501765
# The sample varience for x2, first dimension is 61.75730331454731
# the summ of x1_dist is 1.0
# The sample mean for x1, first dimension is 0.0048418217141861074
# The sample varience for x1, first dimension is 0.10614087316612766
# The sample mean for x2, first dimension is 0.002765867565598394
# The sample varience for x2, first dimension is 0.16570931735452704

# %%
x1 = X1.T
x1 = np.append(x1,np.zeros((len(x1),1)),axis = 1)
x2 = X2.T
x2 = np.append(x2,np.ones((len(x2),1)),axis = 1)
X = np.append(x1,x2,axis = 0)
np.random.seed(0)
np.random.shuffle(X)

# %%
print(X)
# Out:
# [[ 46.    1.  101.  ... 156.    0.    1. ]
#  [ 58.    0.  150.  ... 162.    1.    1. ]
#  [ 48.    1.  124.  ... 175.    0.    1. ]
#  ...
#  [ 52.    1.  128.  ... 156.    1.    0. ]
#  [ 39.    1.  118.  ... 140.    1.2   0. ]
#  [ 51.    1.  125.  ... 125.    1.4   1. ]]

# %%
clf = MaximumLiklihood()

# %%
clf.train(X1,X2)

# %%
sigma1,sigma2,mu1,mu2 = clf.get_mu_sigma()

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the ML in the 0 set is : 46.666666666666664
# The accuracy for the ML in the 1 set is : 35.0
# The accuracy for the ML in the 2 set is : 41.66666666666667
# The accuracy for the ML in the 3 set is : 45.0
# The accuracy for the ML in the 4 set is : 48.333333333333336
# The average accuracy for the ML is 43.33333333333333

# %%
clf = Baysian(sigma1,sigma2,(sigma1+sigma2)/2,(mu1+mu2)/2)

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the Bayesian in the 0 set is : 45.0
# The accuracy for the Bayesian in the 1 set is : 35.0
# The accuracy for the Bayesian in the 2 set is : 55.00000000000001
# The accuracy for the Bayesian in the 3 set is : 45.0
# The accuracy for the Bayesian in the 4 set is : 48.333333333333336
# The average accuracy for the Bayesian is 45.66666666666667

# %%
clf = Parzen_window(1)

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the Parzen in the 0 set is : 71.66666666666667
# The accuracy for the Parzen in the 1 set is : 61.66666666666667
# The accuracy for the Parzen in the 2 set is : 71.66666666666667
# The accuracy for the Parzen in the 3 set is : 70.0
# The accuracy for the Parzen in the 4 set is : 66.66666666666666
# The average accuracy for the Parzen is 68.33333333333333

# %%
clf = KNN(3)

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the KNN in the 0 set is : 71.66666666666667
# The accuracy for the KNN in the 1 set is : 60.0
# The accuracy for the KNN in the 2 set is : 65.0
# The accuracy for the KNN in the 3 set is : 65.0
# The accuracy for the KNN in the 4 set is : 58.333333333333336
# The average accuracy for the KNN is 64.0

# %%
clf = Perceptron(50,0.9)

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the Perceptron in the 0 set is : 70.0
# The accuracy for the Perceptron in the 1 set is : 70.0
# The accuracy for the Perceptron in the 2 set is : 73.33333333333333
# The accuracy for the Perceptron in the 3 set is : 76.66666666666667
# The accuracy for the Perceptron in the 4 set is : 60.0
# The average accuracy for the Perceptron is 70.0

# %% [markdown]
# display on x0 and x3

# %%
clf.display(1,120,150,1.8)

# %% [markdown]
# display on x5 and x0

# %%
clf.display(1,120,150,1.8)

# %%
clf = Ho_Kashyap(50,1)

# %%
K_cross_validation(5,clf,X)
# Out:
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 0 set is : 81.66666666666667
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 1 set is : 73.33333333333333
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 2 set is : 75.0
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 3 set is : 76.66666666666667
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 4 set is : 65.0
# The average accuracy for the Ho_Kashyap is 74.33333333333334

# %%
clf.display(1,120,150,1.8)

# %%
clf.display_x3(1,120,150,1.8)

# %%
clf = Fisher_descriminate()

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the Fisher_descriminate in the 0 set is : 73.33333333333333
# The accuracy for the Fisher_descriminate in the 1 set is : 65.0
# The accuracy for the Fisher_descriminate in the 2 set is : 70.0
# The accuracy for the Fisher_descriminate in the 3 set is : 61.66666666666667
# The accuracy for the Fisher_descriminate in the 4 set is : 60.0
# The average accuracy for the Fisher_descriminate is 66.0

# %%
clf.display(1,120,150,1.8)
# Out:
# [ 5.67390731e-04 -2.16164672e-03  9.41545465e-05  3.64592236e-05
#  -3.14106979e-04  1.77752962e-03]

# %%
clf.display_x3(1,120,150,1.8)

# %%
w1, v1 = LA.eig(sigma1)
w2, v2 = LA.eig(sigma2)
X1_after,X2_after,sigma1_diag,sigma2_diag,mu1_diag,mu2_diag,v_z = diagonalize(X1,w1,v1,X2,w2,v2,sigma1,sigma2,mu1,mu2)
# Out:
# The sigma for x1 after digonalizing
# [[ 2.44241933e+03  4.75882054e-13 -6.79777756e-13 -5.82360118e-13
#   -2.35087010e-14 -1.71782931e-15]
#  [ 4.75090325e-13  5.06451453e+02 -2.91737525e-13 -8.97977484e-14
#   -2.16124751e-14  1.05665532e-14]
#  [-6.84426863e-13 -2.91730049e-13  3.45189352e+02 -5.98547122e-14
#    2.60376745e-15 -5.12500237e-15]
#  [-5.80729895e-13 -8.71130115e-14 -5.21920840e-14  5.64875646e+01
#    1.37164288e-15  7.70552877e-15]
#  [-2.34953929e-14 -2.16422276e-14  2.63047929e-15  1.14901450e-15
#    1.57471753e+00 -3.33498015e-15]
#  [-1.76863158e-15  1.05660925e-14 -5.24585001e-15  7.70326315e-15
#   -3.33318545e-15  1.26759661e-01]]
# The sigma for x1 after converting to identitiy
# [[ 1.00000000e+00  4.27878340e-16 -7.40334758e-16 -1.56785208e-15
#   -3.79068055e-16 -9.76291166e-17]
#  [ 4.27166475e-16  1.00000000e+00 -6.97741715e-16 -5.30909029e-16
#   -7.65304494e-16  1.31878470e-15]
#  [-7.45398024e-16 -6.97723833e-16  1.00000000e+00 -4.28640523e-16
#    1.11679167e-16 -7.74773648e-16]
#  [-1.56346313e-15 -5.15036124e-16 -3.73765763e-16  1.00000000e+00
#    1.45433112e-16  2.87962202e-15]
#  [-3.78853468e-16 -7.66358042e-16  1.12824875e-16  1.21828179e-16
#    1.00000000e+00 -7.46451143e-15]
#  [-1.00516354e-16  1.31872720e-15 -7.93042822e-16  2.87877534e-15
#   -7.46049444e-15  1.00000000e+00]]
# the sigma for x2 after diagonalizing
# [[ 2.17931150e+00  1.11022302e-16 -1.56125113e-17 -3.88578059e-16
#   -2.77555756e-17 -3.33066907e-16]
#  [ 0.00000000e+00  1.53095415e+00 -8.44376652e-16  3.60822483e-16
#   -2.35922393e-16  2.77555756e-17]
#  [-2.60208521e-17 -7.58941521e-16  1.12630454e+00 -1.99276359e-16
#   -1.36934734e-16 -8.85251074e-17]
#  [-3.88578059e-16  4.02455846e-16 -1.34441069e-16  6.63382619e-01
#   -3.67761377e-16 -7.43329009e-16]
#  [-2.28983499e-16 -2.49800181e-16  1.97866896e-18 -4.26741975e-16
#    4.28256154e-01 -4.55798593e-16]
#  [-3.01841885e-16  6.33174069e-17 -1.31120700e-16 -7.53737350e-16
#   -3.75784473e-16  3.40236301e-01]]
# [2.1793115  1.53095415 1.12630454 0.66338262 0.42825615 0.3402363 ]
# The sigma for x1 after all the changes
# [[ 1.00000000e+00 -3.80806497e-14  5.62050406e-16 -2.43138842e-14
#    7.84095011e-15  1.00024156e-14]
#  [-3.81916720e-14  1.00000000e+00  3.93782229e-16  1.12548859e-14
#   -4.93355357e-15 -3.54230534e-15]
#  [ 5.68989300e-16  2.95336672e-16  1.00000000e+00 -3.69929781e-16
#    9.29920203e-16 -1.14735695e-16]
#  [-2.43693954e-14  1.13381526e-14 -3.49763621e-16  1.00000000e+00
#   -2.50841015e-15 -3.99159872e-15]
#  [ 7.79931675e-15 -4.94049246e-15  9.26017076e-16 -2.57432964e-15
#    1.00000000e+00 -3.16587034e-16]
#  [ 1.00093545e-14 -3.53536644e-15 -1.07715486e-16 -4.00027234e-15
#   -3.51281504e-16  1.00000000e+00]]
# checking
# [[ 2.17931150e+00  1.11022302e-16 -1.56125113e-17 -3.88578059e-16
#   -2.77555756e-17 -3.33066907e-16]
#  [ 0.00000000e+00  1.53095415e+00 -8.44376652e-16  3.60822483e-16
#   -2.35922393e-16  2.77555756e-17]
#  [-2.60208521e-17 -7.58941521e-16  1.12630454e+00 -1.99276359e-16
#   -1.36934734e-16 -8.85251074e-17]
#  [-3.88578059e-16  4.02455846e-16 -1.34441069e-16  6.63382619e-01
#   -3.67761377e-16 -7.43329009e-16]
#  [-2.28983499e-16 -2.49800181e-16  1.97866896e-18 -4.26741975e-16
#    4.28256154e-01 -4.55798593e-16]
#  [-3.01841885e-16  6.33174069e-17 -1.31120700e-16 -7.53737350e-16
#   -3.75784473e-16  3.40236301e-01]]

# %%
x1 = X1_after.T
x1 = np.append(x1,np.zeros((len(x1),1)),axis = 1)
x2 = X2_after.T
x2 = np.append(x2,np.ones((len(x2),1)),axis = 1)
X = np.append(x1,x2,axis = 0)
np.random.seed(0)
np.random.shuffle(X)

# %%
clf = MaximumLiklihood()

# %%
clf.train(X1_after,X2_after)

# %%
sigma1,sigma2,mu1,mu2 = clf.get_mu_sigma()

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the ML in the 0 set is : 46.666666666666664
# The accuracy for the ML in the 1 set is : 35.0
# The accuracy for the ML in the 2 set is : 41.66666666666667
# The accuracy for the ML in the 3 set is : 45.0
# The accuracy for the ML in the 4 set is : 48.333333333333336
# The average accuracy for the ML is 43.33333333333333

# %%
clf = Baysian(sigma1,sigma2,(sigma1+sigma2)/2,(mu1+mu2)/2)

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the Bayesian in the 0 set is : 45.0
# The accuracy for the Bayesian in the 1 set is : 35.0
# The accuracy for the Bayesian in the 2 set is : 55.00000000000001
# The accuracy for the Bayesian in the 3 set is : 45.0
# The accuracy for the Bayesian in the 4 set is : 48.333333333333336
# The average accuracy for the Bayesian is 45.66666666666667

# %%
clf = Parzen_window(1)

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the Parzen in the 0 set is : 65.0
# The accuracy for the Parzen in the 1 set is : 80.0
# The accuracy for the Parzen in the 2 set is : 68.33333333333333
# The accuracy for the Parzen in the 3 set is : 73.33333333333333
# The accuracy for the Parzen in the 4 set is : 58.333333333333336
# The average accuracy for the Parzen is 68.99999999999999

# %%
clf = KNN(3)

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the Perceptron in the 0 set is : 80.0
# The accuracy for the Perceptron in the 1 set is : 73.33333333333333
# The accuracy for the Perceptron in the 2 set is : 73.33333333333333
# The accuracy for the Perceptron in the 3 set is : 75.0
# The accuracy for the Perceptron in the 4 set is : 71.66666666666667
# The average accuracy for the Perceptron is 74.66666666666666

# %%
clf = Perceptron(50,0.9)

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the Perceptron in the 0 set is : 75.0
# The accuracy for the Perceptron in the 1 set is : 71.66666666666667
# The accuracy for the Perceptron in the 2 set is : 71.66666666666667
# The accuracy for the Perceptron in the 3 set is : 76.66666666666667
# The accuracy for the Perceptron in the 4 set is : 71.66666666666667
# The average accuracy for the Perceptron is 73.33333333333334

# %%
clf.display(0,0,0,0)

# %%
X[:,2]
# Out:
# array([2.73557062, 3.6002322 , 3.74131905, 2.43857075, 4.29379729,
#        3.11092558, 2.87504037, 3.00976495, 9.03492388, 3.11883278,
#        2.78846234, 3.82868031, 4.0631894 , 4.3486627 , 4.94562938,
#        3.21394786, 3.0798629 , 2.79694747, 2.74760147, 1.30094922,
#        3.25521514, 3.04141397, 2.84486431, 2.59559054, 0.63210015,
#        2.69423   , 1.92371885, 4.62789537, 4.99753996, 6.00155976,
#        3.24625612, 2.35535469, 2.44379664, 2.99937794, 2.42166441,
#        3.99246343, 1.91590395, 6.20546295, 3.57326845, 2.26625151,
#        3.12047289, 3.117778  , 3.23591099, 1.02615033, 3.00882406,
#        4.05904333, 4.63799547, 3.35309026, 3.45664624, 3.99163639,
#        2.65232955, 1.76184702, 2.20724497, 3.36150754, 5.04310207,
#        3.01094833, 1.95585667, 2.414351  , 2.34510222, 1.74820471,
#        3.693434  , 4.51090244, 2.98589039, 3.89541842, 3.01970371,
#        2.20214391, 3.30938534, 5.06148571, 1.88522535, 3.47491888,
#        4.44483479, 3.39067809, 3.27648854, 1.75112377, 3.36010509,
#        1.76686452, 2.10913562, 3.81500966, 2.80788753, 1.9405588 ,
#        5.93541636, 2.14978472, 3.3968061 , 2.22617601, 3.20519037,
#        3.70075393, 3.35118259, 3.00375834, 2.37389077, 4.81164201,
#        3.61955383, 0.46864267, 3.49202337, 3.44094114, 1.55167663,
#        4.45873965, 3.60777976, 2.04587001, 3.61589329, 2.41067279,
#        3.34928041, 3.43685149, 5.64444271, 3.16118151, 3.43480706,
#        3.27613119, 5.24449823, 2.47860841, 4.18536509, 3.91855004,
#        0.68469988, 3.17622545, 2.01034162, 4.77126205, 2.73067396,
#        2.86010614, 2.87812322, 1.97298637, 1.60458847, 3.68251986,
#        2.39858737, 0.91070138, 3.48786652, 0.92556104, 3.79888014,
#        3.01757649, 1.89110286, 3.87224014, 1.73041632, 2.46953754,
#        3.02588036, 3.56238458, 2.09061656, 2.50017123, 2.00791215,
#        2.34163924, 3.14842561, 3.53843938, 3.72147438, 2.28035529,
#        3.66402216, 2.28640527, 3.40798422, 3.81116014, 2.1397373 ,
#        2.70690743, 2.49442279, 2.95902866, 2.47604357, 2.20034447,
#        2.37046751, 4.20435435, 1.8703237 , 5.11343852, 2.5846653 ,
#        2.94011055, 3.18857698, 3.05025626, 1.98930891, 4.05924508,
#        2.60756182, 3.50399608, 3.18507979, 3.83034601, 3.32796158,
#        4.15066491, 2.04542866, 3.33964344, 3.25831772, 2.94602666,
#        2.94980671, 1.87131634, 5.3600275 , 2.4141149 , 3.30584184,
#        2.55690358, 4.55808642, 2.84908637, 1.91353138, 2.78008564,
#        2.23287768, 3.25793723, 2.8457868 , 2.28227623, 4.22478326,
#        2.96606905, 4.51561185, 3.85923676, 3.69065698, 1.90909668,
#        2.61314766, 3.44033324, 4.287308  , 1.98887565, 3.36476714,
#        2.97147852, 3.2701502 , 4.2722625 , 3.19962986, 2.72331446,
#        2.66402883, 1.790139  , 4.13626639, 3.13997387, 3.68593079,
#        2.98451033, 3.70282038, 3.11716423, 3.83143781, 2.68896976,
#        5.08014947, 3.23741809, 2.21191514, 3.02020708, 3.67095621,
#        3.01694936, 1.8033971 , 2.69795263, 3.16459218, 2.02023687,
#        3.02319253, 1.80304211, 3.76019361, 2.23622778, 2.90502683,
#        3.40967599, 2.41165084, 2.89648084, 3.58693607, 3.27543794,
#        4.32300254, 3.05434771, 3.64210398, 2.15332368, 5.26617066,
#        3.57992871, 4.40763594, 3.7584153 , 2.79007787, 2.87673473,
#        3.203238  , 4.01316639, 2.93943206, 3.62584676, 1.34144228,
#        3.89158182, 3.46640363, 2.36455816, 1.9874705 , 2.53946577,
#        2.12773363, 3.15485232, 3.32471456, 1.66153653, 1.48209752,
#        4.56514137, 3.5224661 , 2.70927127, 2.76372725, 4.32024387,
#        2.29997483, 3.53903369, 4.96242973, 3.33038736, 2.30887983,
#        1.76003423, 2.26985874, 3.15542732, 2.9133999 , 4.74830596,
#        3.47538792, 3.08592816, 3.77260228, 1.63678671, 4.29331617,
#        4.58166696, 3.7244681 , 4.10924708, 1.71427448, 1.25464553,
#        3.14409213, 3.9363407 , 4.28552309, 1.75411272, 0.6149209 ,
#        4.28334869, 3.04908195, 1.41376878, 2.36271847, 3.28415407,
#        4.45007221, 3.36296028, 2.36368758, 2.55356572, 3.70221029,
#        2.09128407, 4.14183537, 3.07497965, 2.98224258, 2.47896045,
#        3.19081382, 2.43048708])

# %%
clf = Ho_Kashyap(50,1)

# %%
K_cross_validation(5,clf,X)
# Out:
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 0 set is : 81.66666666666667
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 1 set is : 73.33333333333333
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 2 set is : 75.0
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 3 set is : 76.66666666666667
# Finished by maximum iterations
# The accuracy for the Ho_Kashyap in the 4 set is : 65.0
# The average accuracy for the Ho_Kashyap is 74.33333333333334

# %%
clf = Fisher_descriminate()

# %%
K_cross_validation(5,clf,X)
# Out:
# The accuracy for the Fisher_descriminate in the 0 set is : 80.0
# The accuracy for the Fisher_descriminate in the 1 set is : 63.33333333333333
# The accuracy for the Fisher_descriminate in the 2 set is : 66.66666666666666
# The accuracy for the Fisher_descriminate in the 3 set is : 65.0
# The accuracy for the Fisher_descriminate in the 4 set is : 60.0
# The average accuracy for the Fisher_descriminate is 67.0
